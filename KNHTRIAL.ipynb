# %%
# First, install necessary packages (if not already installed)
# !pip install pandas openpyxl matplotlib seaborn scipy

# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

# %%
# Load the Excel file into a pandas DataFrame
excel_file_path = "group1.xlsx"  # Replace with your file path
df = pd.read_excel(excel_file_path)

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#      diagnosis  apperance  bathing  breathing  changesurination  constipation  \
# 0  anal cancer        NaN      NaN        NaN               NaN           NaN
# 1  anal cancer        NaN      NaN        NaN               NaN           NaN
# 2  anal cancer        NaN      NaN        NaN               NaN           NaN
# 3  anal cancer        NaN      NaN        NaN               NaN           NaN
# 4  anal cancer        NaN      NaN        NaN               NaN           NaN
#
#    diarrhea  eating  fatigue  feelingswollen  ...  substance  tinglinghands  \
# 0       NaN     NaN      NaN             NaN  ...        NaN            NaN
# 1       NaN     NaN      NaN             NaN  ...        NaN            NaN
# 2       NaN     NaN      NaN             NaN  ...        NaN            NaN
# 3       NaN     NaN      NaN             NaN  ...        NaN            NaN
# 4       NaN     NaN      NaN             NaN  ...        NaN            NaN
#
# ...

# %%
# Task 3: Get column info
df.info()
df.columns

# Task 4: Count non-null values in each column
df.count()

# Task 5: Check unique values in diagnosis column
df['diagnosis'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   diagnosis         5282 non-null   object
#  1   apperance         117 non-null    float64
#  2   bathing           11 non-null     float64
#  3   breathing         115 non-null    float64
#  4   changesurination  134 non-null    float64
#  5   constipation      226 non-null    float64
#  6   diarrhea          68 non-null     float64
#  7   eating            1348 non-null   float64
#  8   fatigue           1306 non-null   float64
#  9   feelingswollen    224 non-null    float64
#  10  fever             49 non-null     float64
#  11  gettingaround     129 non-null    float64
#  12  indigestion       28 non-null     float64
#  13  memory            11 non-null     float64
#  14  sores             6 non-null      float64
#  15  nausea            232 non-null    float64
# ...

# %%
# Task 6: Rename column headers for consistency
df.columns = [col.lower().replace(' ', '_') for col in df.columns]
df.columns


df.columns = [col.upper().replace(' ', '_') for col in df.columns]
df.columns
# Out:
# Index(['DIAGNOSIS', 'APPERANCE', 'BATHING', 'BREATHING', 'CHANGESURINATION',
#        'CONSTIPATION', 'DIARRHEA', 'EATING', 'FATIGUE', 'FEELINGSWOLLEN',
#        'FEVER', 'GETTINGAROUND', 'INDIGESTION', 'MEMORY', 'SORES', 'NAUSEA',
#        'NOSEDRY', 'PAIN', 'SEXUAL', 'SKINDRY', 'SLEEP', 'SUBSTANCE',
#        'TINGLINGHANDS', 'DISCHARGE', 'VISION', 'SPEECH', 'BLEEDING',
#        'DIZZINESS', 'HEARING', 'VOMITING', 'NUMBNESS'],
#       dtype='object')
